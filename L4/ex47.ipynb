# %% [markdown]
# <a href="https://colab.research.google.com/github/aquapathos/Semi3B/blob/master/L4/ex47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ksize = (3,3)

import cv2

img = cv2.imread("prof.jpg",-1)

print(img.shape)
# Out:
# (358, 488, 3)

# %%
print(img.shape[0],img.shape[1],img.shape[2])
# Out:
# 358 488 3

# %%
import cv2
from google.colab.patches import cv2_imshow
input = cv2.imread("prof.jpg") # 第２引数は省略できる　省略した場合は 1 (２４ビットカラー) 
 
w = input.shape[1]
h = input.shape[0]
c = input.shape[2]
out1 = cv2.resize(input, (2*w,2*h)) # 2倍
out2 = cv2.resize(input, (int(w/2),int(h/2))) # 1/2
print("オリジナルサイズ")
cv2_imshow(input)
print("ダブルサイズ")
cv2_imshow(out1)
print("ハーフサイズ")
cv2_imshow(out2)
# Out:
# オリジナルサイズ
# <PIL.Image.Image image mode=RGB size=488x358 at 0x7FEEE861D128>
# ダブルサイズ
# <PIL.Image.Image image mode=RGB size=976x716 at 0x7FEEE861D208>
# ハーフサイズ
# <PIL.Image.Image image mode=RGB size=244x179 at 0x7FEEE861D208>
