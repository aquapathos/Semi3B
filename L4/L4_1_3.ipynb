# %% [markdown]
# <a href="https://colab.research.google.com/github/aquapathos/Semi3B/blob/master/L4/L4_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ネット上の画像の直接表示 （colab 版）

# %%
import urllib.request
import cv2
from google.colab.patches import cv2_imshow
 
def main():
 url = 'https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_(test_image).png' # 画像URL
 img_path, header = urllib.request.urlretrieve(url)
 print(header) # アクセスが拒否されていないかどうかのチェック用
 img = cv2.imread(img_path,1)
 cv2_imshow(img)

if __name__ == '__main__':
 main()
# Out:
# Date: Mon, 15 Apr 2019 12:42:47 GMT
# Content-Type: image/png
# Content-Length: 473831
# Connection: close
# X-Object-Meta-Sha1Base36: 7ceymti31x4aj1z8gafb00gzips9qit
# Last-Modified: Thu, 10 May 2018 15:16:16 GMT
# Etag: 814a0034f5549e957ee61360d87457e5
# X-Timestamp: 1525965375.19978
# X-Trans-Id: tx7be26ff0dc79402a8af5f-005cb36f32
# X-Varnish: 89249245 15887114, 8024933 17532823, 385107943
# Via: 1.1 varnish (Varnish/5.1), 1.1 varnish (Varnish/5.1), 1.1 varnish (Varnish/5.1)
# Accept-Ranges: bytes
# Age: 68884
# X-Cache: cp2002 hit/14, cp4026 hit/1, cp4022 pass
# X-Cache-Status: hit-local
# Server-Timing: cache;desc="hit-local"
# Strict-Transport-Security: max-age=106384710; includeSubDomains; preload
# X-Analytics: https=1;nocookies=1
# X-Client-IP: 35.233.177.246
# Access-Control-Allow-Origin: *
# Access-Control-Expose-Headers: Age, Date, Content-Length, Content-Range, X-Content-Duration, X-Cache, X-Varnish
# Timing-Allow-Origin: *
# ...
